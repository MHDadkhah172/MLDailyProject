# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('data/car data.csv')
df = pd.DataFrame(data)
df.drop('Car_Name', axis=1, inplace=True)

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           301 non-null    int64
#  1   Selling_Price  301 non-null    float64
#  2   Present_Price  301 non-null    float64
#  3   Kms_Driven     301 non-null    int64
#  4   Fuel_Type      301 non-null    str
#  5   Seller_Type    301 non-null    str
#  6   Transmission   301 non-null    str
#  7   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), str(3)
# memory usage: 18.9 KB

# %%
sns.regplot(x='Year', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Year')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.show()

# %%
sns.regplot(x='Present_Price', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Present_Price')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.show()

# %%
df = df[df['Present_Price'] < 80]

# %%
sns.regplot(x='Kms_Driven', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Kms_Driven')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.show()

# %%
sns.regplot(x='Fuel_Type', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Fuel_Type')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.regplot(x='Fuel_Type', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
#       2 plt.xlabel('Fuel_Type')
#       3 plt.ylabel('Selling_Price')
#       4 plt.grid(True)
#
# File ~\Desktop\machinlearning\Projects\ML\.venv\Lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# ...

# %%
sns.regplot(x='Seller_Type', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Seller_Type')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.regplot(x='Seller_Type', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
#       2 plt.xlabel('Seller_Type')
#       3 plt.ylabel('Selling_Price')
#       4 plt.grid(True)
#
# File ~\Desktop\machinlearning\Projects\ML\.venv\Lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# ...

# %%
sns.regplot(x='Transmission', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Transmission')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.regplot(x='Transmission', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
#       2 plt.xlabel('Transmission')
#       3 plt.ylabel('Selling_Price')
#       4 plt.grid(True)
#
# File ~\Desktop\machinlearning\Projects\ML\.venv\Lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# ...

# %%
sns.regplot(x='Owner', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Owner')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.show()

# %%
##### deleting one row that has 3 Owner
df = df[df['Owner'] < 3]

# %%
plt.scatter(df['Year'], df['Kms_Driven'], alpha=0.5)
plt.xlabel('Year')
plt.ylabel('Kms_Driven')
plt.grid(True)
plt.show()

# %%
max_kms_index = df['Kms_Driven'].idxmax()
df.loc[max_kms_index]

# %%
###### delete row with 500k km Kms_Driven
df = df[df['Kms_Driven'] < 400000]

# %%
plt.scatter(df['Fuel_Type'], df['Present_Price'], alpha=0.5)
plt.xlabel('Fuel_Type')
plt.ylabel('Present_Price')
plt.grid(True)
plt.show()

# %%
max_Presint_Price = df['Present_Price'].idxmax()
df.loc[max_Presint_Price]
# Out:
# Year                  2017
# Selling_Price         33.0
# Present_Price        36.23
# Kms_Driven            6000
# Fuel_Type           Diesel
# Seller_Type         Dealer
# Transmission     Automatic
# Owner                    0
# Name: 64, dtype: object

# %%
plt.scatter(df['Year'], df['Selling_Price'], alpha=0.5)
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   300.000000     300.000000     300.000000     300.000000  300.000000
# mean   2013.640000       4.560167       7.345233   36810.363333    0.043333
# std       2.888751       4.778361       7.123373   38879.195963    0.248317
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.875000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.555000       6.250000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.862500   48191.750000    0.000000
# max    2018.000000      33.000000      36.230000  500000.000000    3.000000

# %%
#### creating new dataset with less noise
df.to_csv('data/dataset_logical_filter.csv', index=False)

# %%
sns.regplot(x='Present_Price', y='Selling_Price', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Present_Price')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.show()

# %%
plt.scatter(df['Present_Price'], df['Selling_Price'], alpha=0.5)
plt.xlabel('Present_Price')
plt.ylabel('Selling_Price')
plt.grid(True)
plt.axline((0, 0), slope=1, color='black', linestyle='--')
max_val = df['Present_Price'].max()
plt.plot([0, max_val], [0, max_val], color='red', linestyle='--', label='y = x (No Depreciation)')
min_ratio = (df['Selling_Price'] / df['Present_Price']).min()
x_vals = np.array([0, max_val])
y_vals = min_ratio * x_vals
plt.plot(x_vals, y_vals,color="purple", label=f'Market Floor (y = {min_ratio:.2f}x)')
print(min_ratio)
plt.show()
# Out:
# 0.10535187526337969

# %%
########creating new feature calle Price_Ratio

# %%
df['Price_Ratio'] = df['Selling_Price'] / df['Present_Price']

# %%
plt.scatter( df['Year'], df['Price_Ratio'], alpha=0.5)

# %%
threshold_ratio = df['Price_Ratio'].quantile(0.02)
threshold_ratio
# Out:
# np.float64(0.2068424465897089)

# %%
df_sorted = df.sort_values(by='Price_Ratio', ascending=True)
df_sorted.head(10)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 85   2006           2.50          23.73      142000    Petrol  Individual
# 77   2004           1.50          12.35      135154    Petrol      Dealer
# 200  2006           0.10           0.75       92233    Petrol  Individual
# 37   2003           0.35           2.28      127000    Petrol  Individual
# 94   2008           4.00          22.78       89000    Petrol      Dealer
# 90   2009           3.80          18.61       62000    Petrol      Dealer
# 199  2007           0.12           0.58       53000    Petrol  Individual
# 78   2010           5.25          22.83       80000    Petrol      Dealer
# 55   2009           3.60          15.04       70000    Petrol      Dealer
# 47   2006           1.05           4.15       65000    Petrol      Dealer
#
#     Transmission  Owner  Price_Ratio
# 85     Automatic      3     0.105352
# 77     Automatic      0     0.121457
# 200       Manual      0     0.133333
# ...

# %%
df = df[df['Price_Ratio'] >= 0.20]

# %%
plt.scatter( df['Year'], df['Price_Ratio'], alpha=0.5)

# %%
df_sorted = df.sort_values(by='Price_Ratio', ascending=True)
df_sorted.head(10)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 90   2009           3.80         18.610       62000    Petrol      Dealer
# 199  2007           0.12          0.580       53000    Petrol  Individual
# 78   2010           5.25         22.830       80000    Petrol      Dealer
# 55   2009           3.60         15.040       70000    Petrol      Dealer
# 47   2006           1.05          4.150       65000    Petrol      Dealer
# 194  2008           0.20          0.787       50000    Petrol  Individual
# 57   2010           4.75         18.540       50000    Petrol      Dealer
# 92   2005           3.51         13.700       75000    Petrol      Dealer
# 84   2005           3.49         13.460      197176    Diesel      Dealer
# 198  2011           0.15          0.570       35000    Petrol  Individual
#
#     Transmission  Owner  Price_Ratio
# 90        Manual      0     0.204191
# 199       Manual      0     0.206897
# 78     Automatic      0     0.229961
# ...

# %%
###### creating new dataset with less noise (Price Ratio > .20)

# %%
df.drop('Price_Ratio', axis=1, inplace=True)

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    234
# Diesel     59
# CNG         2
# Name: count, dtype: int64

# %%
df.to_csv('data/dataset_Price_Ratio_.20.csv', index=False)

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   295.000000     295.000000     295.000000     295.000000  295.000000
# mean   2013.779661       4.608814       7.259932   35449.905085    0.033898
# std       2.694589       4.800350       7.039478   37650.109722    0.181275
# min    2003.000000       0.120000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.650000       6.100000   31427.000000    0.000000
# 75%    2016.000000       6.000000       9.685000   46603.000000    0.000000
# max    2018.000000      33.000000      36.230000  500000.000000    1.000000

# %%
#deleting cng fuel type (because there is only 2 data)

# %%
df_no_cng = pd.read_csv("data/dataset_logical_filter.csv")
df_no_cng
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 295  2016           9.50          11.60       33988    Diesel      Dealer
# 296  2015           4.00           5.90       60000    Petrol      Dealer
# 297  2009           3.35          11.00       87934    Petrol      Dealer
# 298  2017          11.50          12.50        9000    Diesel      Dealer
# 299  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
plt.scatter(df_no_cng['Fuel_Type'], df_no_cng['Selling_Price'], alpha=0.5)

# %%
cols_to_compare = ['Selling_Price', 'Present_Price', 'Kms_Driven', 'Year']
main_fuels = df_no_cng[df_no_cng['Fuel_Type'].isin(['Petrol', 'Diesel'])]

main_fuels = df_no_cng[df_no_cng['Fuel_Type'].isin(['Petrol', 'Diesel'])]
print(main_fuels.groupby('Fuel_Type')[cols_to_compare].mean().round(2))
print(main_fuels.groupby('Fuel_Type')[cols_to_compare].median().round(2))
quartiles = main_fuels.groupby('Fuel_Type')['Selling_Price'].describe()[['25%', '50%', '75%']]
print(quartiles.round(2))
cng_cars = df_no_cng[df_no_cng['Fuel_Type'] == 'CNG'][cols_to_compare]
print(cng_cars)
# Out:
#            Selling_Price  Present_Price  Kms_Driven     Year
# Fuel_Type
# Diesel              9.86          14.51    49901.61  2014.07
# Petrol              3.26           5.58    33528.94  2013.54
#            Selling_Price  Present_Price  Kms_Driven    Year
# Fuel_Type
# Diesel              7.75          10.38     45000.0  2014.0
# Petrol              2.65           4.60     25870.0  2014.0
#             25%   50%    75%
# Fuel_Type
# Diesel     5.08  7.75  12.12
# Petrol     0.60  2.65   5.20
#     Selling_Price  Present_Price  Kms_Driven  Year
# 18           3.25           5.09       35500  2015
# 35           2.95           7.74       49998  2011

# %%
df_no_cng['Fuel_Type'] = df_no_cng['Fuel_Type'].replace('CNG', 'Petrol')
print(df_no_cng['Fuel_Type'].value_counts())
# Out:
# Fuel_Type
# Petrol    241
# Diesel     59
# Name: count, dtype: int64

# %%
df_no_cng.to_csv('data/dataset_logical_filter.csv', index=False)

# %%
df_test = pd.read_csv('data/dataset_logical_filter.csv')
print(df_test['Fuel_Type'].value_counts())
# Out:
# Fuel_Type
# Petrol    241
# Diesel     59
# Name: count, dtype: int64

# %%
df_no_cng_price = pd.read_csv("data/dataset_Price_Ratio_.20.csv")
df_no_cng_price['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    234
# Diesel     59
# CNG         2
# Name: count, dtype: int64

# %%
df_no_cng_price['Fuel_Type'] = df_no_cng_price['Fuel_Type'].replace('CNG', 'Petrol')
print(df_no_cng_price['Fuel_Type'].value_counts())
# Out:
# Fuel_Type
# Petrol    236
# Diesel     59
# Name: count, dtype: int64

# %%
df_no_cng_price.to_csv('data/dataset_Price_Ratio_.20.csv', index=False)

# %%
df_no_cng
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 295  2016           9.50          11.60       33988    Diesel      Dealer
# 296  2015           4.00           5.90       60000    Petrol      Dealer
# 297  2009           3.35          11.00       87934    Petrol      Dealer
# 298  2017          11.50          12.50        9000    Diesel      Dealer
# 299  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df_no_cng = df_no_cng[df_no_cng['Selling_Price'] <= 30]

# %%
plt.scatter(df_no_cng['Fuel_Type'], df_no_cng['Selling_Price'], alpha=0.5)

# %%
plt.scatter(df_no_cng['Kms_Driven'], df_no_cng['Selling_Price'], alpha=0.5)

# %%
df_no_cng = df_no_cng[df_no_cng['Kms_Driven'] <= 300000]

# %%
plt.scatter(df_no_cng['Owner'], df_no_cng['Selling_Price'], alpha=0.5)

# %%
df_no_cng = df_no_cng[df_no_cng['Owner'] <= 2]

# %%
df_no_cng.to_csv('data/dataset_logical_filter.csv', index=False)

# %%
plt.scatter(df_no_cng['Present_Price'], df_no_cng['Selling_Price'], alpha=0.5)

# %%
df_no_cng['Car_Age'] = 2019 - df_no_cng['Year']
df_no_cng['Age_Squared'] = df_no_cng['Car_Age'] ** 2
df_no_cng['Kms_Squared'] = df_no_cng['Kms_Driven'] ** 2

# %%
plt.scatter(df_no_cng['Car_Age'], df_no_cng['Selling_Price'], alpha=0.5)

# %%
df_no_cng['Age_Log'] = np.log1p(df_no_cng['Car_Age'])

# %%
df_no_cng['Selling_Price_Log'] = np.log1p(df_no_cng['Selling_Price'])

# %%
plt.scatter(df_no_cng['age_log'], df_no_cng['Selling_Price'], alpha=0.5)

# %%
plt.scatter(df_no_cng['Car_Age'], df_no_cng['Selling_Price_Log'], alpha=0.5)
